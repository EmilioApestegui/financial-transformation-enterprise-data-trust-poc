# %%
from pathlib import Path\nimport pandas as pd\n\nproject_root = Path.cwd().resolve().parents[0]\nworkbook_path = project_root / 'data' / 'financial_transformation_data_trust_poc_data.xlsx'\nworkbook_path

# %%
sheets = pd.read_excel(workbook_path, sheet_name=None)\n{name: df.shape for name, df in sheets.items()}

# %%
sheets['kpi_submissions']
